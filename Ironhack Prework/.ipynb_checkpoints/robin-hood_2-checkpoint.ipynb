# %% [markdown]
# <img src="https://bit.ly/2VnXWr2" width="100" align="left"/>

# %% [markdown]
# # Robin Hood
# Robin Hood has entered a competition to win the archery contest in Sherwood. With his bow and arrows, he needs to shoot on a target and try to hit as close as possible to the center.
#
# ![](images/arrows.jpg)
#
# ## Context
# In this challenge, the landing position of arrows shot by archers in the competition will be represented using 2-dimensional coordinates.
#
# In the 2-dimensional space, a point can be defined by a pair of values that correspond to the horizontal coordinate (x) and the vertical coordinate (y). For example, in our case, an arrow that hits the center of the archery target will land in position (0, 0) on the coordinate axes.
#
# The space can be divided into 4 zones (quadrants): Q1, Q2, Q3, Q4. If a point is in Q1, both its x coordinate and y coordinate are positive. Any point with a null x or y coordinate is considered to not belong to any quadrant.
#
# If you want to know more about the cartesian coordinate system, you can check this [link](https://en.wikipedia.org/wiki/Cartesian_coordinate_system).
#
# ## Tools
# You don't necessarily need to use all the tools. Maybe you opt to use some of them or completely different ones, they are given to help you shape the exercise. Programming exercises can be solved in many different ways.
# * Data structures: **lists, sets, tuples**
# * Conditional statements: **if-elif-else**
# * Loop: **while/for**
# * Minimum (optional sorting)
#
# ## Tasks
# Robin Hood has hit the following points:

# %%
points = [(4, 5), (-0, 2), (4, 7), (1, -3), (3, -2), (4, 5), (3, 2), (5, 7), (-5, 7), (2, 2), (-4, 5), (0, -2),
          (-4, 7), (-1, 3), (-3, 2), (-4, -5), (-3, 2), (5, 7), (5, 7), (2, 2), (9, 9), (-8, -9)]
p=0
d=0
new_list=[]

uniques = set(points)
dup=list(uniques)

points.sort()
print("lista 1 ", points)
dup.sort()
print("lista 2", dup)
# Out:
# lista 1  [(-8, -9), (-5, 7), (-4, -5), (-4, 5), (-4, 7), (-3, 2), (-3, 2), (-1, 3), (0, -2), (0, 2), (1, -3), (2, 2), (2, 2), (3, -2), (3, 2), (4, 5), (4, 5), (4, 7), (5, 7), (5, 7), (5, 7), (9, 9)]
# lista 2 [(-8, -9), (-5, 7), (-4, -5), (-4, 5), (-4, 7), (-3, 2), (-1, 3), (0, -2), (0, 2), (1, -3), (2, 2), (3, -2), (3, 2), (4, 5), (4, 7), (5, 7), (9, 9)]

# %% [markdown]
# #### 1. Robin Hood is famous for hitting an arrow with another arrow. Find the coordinates of the points where an arrow hits another arrow.

# %%
r=0
i=0
j=0
new_list=[]


while r<=15:
    r = r+1
    if points[i] == dup[j]:
        print("points", points[i])
        print("dup", dup[j])
        print("IDLE")
        i = i + 1
        j = j + 1
    elif points[i] != dup[j]:
        print("points", points[i])
        print("dup" , dup[j])
        print("FOUND")
        new_list.append(points[i])
        print("same spot", new_list)
        i = i + 2
        j = j + 1
# Out:
# points (-8, -9)
# dup (-8, -9)
# IDLE
# points (-5, 7)
# dup (-5, 7)
# IDLE
# points (-4, -5)
# dup (-4, -5)
# IDLE
# points (-4, 5)
# dup (-4, 5)
# IDLE
# points (-4, 7)
# dup (-4, 7)
# IDLE
# points (-3, 2)
# dup (-3, 2)
# IDLE
# points (-3, 2)
# dup (-1, 3)
# FOUND
# same spot [(-3, 2)]
# points (0, -2)
# dup (0, -2)
# IDLE
# points (0, 2)
# dup (0, 2)
# IDLE
# points (1, -3)
# dup (1, -3)
# IDLE
# points (2, 2)
# dup (2, 2)
# IDLE
# points (2, 2)
# dup (3, -2)
# FOUND
# same spot [(-3, 2), (2, 2)]
# points (3, 2)
# dup (3, 2)
# IDLE
# points (4, 5)
# dup (4, 5)
# IDLE
# points (4, 5)
# dup (4, 7)
# FOUND
# same spot [(-3, 2), (2, 2), (4, 5)]
# points (5, 7)
# dup (5, 7)
# IDLE

# %% [markdown]
# #### 2. Calculate how many arrows have fallen in each quadrant.
# **Note**: the arrows that fall in the axis (x=0 or y=0) don't belong to any quadrant.

# %%
points = [(4, 5), (-0, 2), (4, 7), (1, -3), (3, -2), (4, 5), (3, 2), (5, 7), (-5, 7), (2, 2), (-4, 5), (0, -2),
          (-4, 7), (-1, 3), (-3, 2), (-4, -5), (-3, 2), (5, 7), (5, 7), (2, 2), (9, 9), (-8, -9)]
Q1=0
Q2=0
Q3=0
Q4=0
QQ1=[]
QQ2=[]
QQ3=[]
QQ4=[]

r=0
x=0
y=0
a=0

while r <= 21:
    x = points[a][0]
    y = points[a][1]
    print(x)
    print(y)
    if (x > 0 and y > 0): 
        Q1=Q1+1
        QQ1.append(points[a])
        print ("lies in First quadrant")  
    elif (x < 0 and y > 0):
        Q2=Q2+1
        QQ2.append(points[a])
        print ("lies in Second quadrant")          
    elif (x < 0 and y < 0):
        Q3=Q3+1
        QQ3.append(points[a])
        print ("lies in Third quadrant")      
    elif (x > 0 and y < 0): 
        Q4=Q4+1
        QQ4.append(points[a])
        print ("lies in Fourth quadrant")      
    else: 
        print ("lies at origin")       
    a = a+1
    r = r+1
    
    
print("\nQ1=",Q1)
print("Q2=",Q2)
print("Q3=",Q3)
print("Q4=",Q4, "\n")

print("Q1", QQ1)
print("Q2", QQ2)
print("Q3", QQ3)
print("Q4", QQ4)
# Out:
# 4
# 5
# lies in First quadrant
# 0
# 2
# lies at origin
# 4
# 7
# lies in First quadrant
# 1
# -3
# lies in Fourth quadrant
# 3
# -2
# lies in Fourth quadrant
# 4
# 5
# lies in First quadrant
# 3
# 2
# lies in First quadrant
# 5
# 7
# lies in First quadrant
# -5
# 7
# lies in Second quadrant
# 2
# 2
# lies in First quadrant
# -4
# 5
# lies in Second quadrant
# 0
# -2
# lies at origin
# -4
# 7
# lies in Second quadrant
# -1
# 3
# lies in Second quadrant
# -3
# 2
# lies in Second quadrant
# -4
# -5
# lies in Third quadrant
# -3
# 2
# lies in Second quadrant
# 5
# 7
# lies in First quadrant
# 5
# 7
# lies in First quadrant
# 2
# 2
# lies in First quadrant
# 9
# 9
# lies in First quadrant
# -8
# -9
# lies in Third quadrant
#
# Q1= 10
# Q2= 6
# Q3= 2
# Q4= 2
#
# Q1 [(4, 5), (4, 7), (4, 5), (3, 2), (5, 7), (2, 2), (5, 7), (5, 7), (2, 2), (9, 9)]
# Q2 [(-5, 7), (-4, 5), (-4, 7), (-1, 3), (-3, 2), (-3, 2)]
# Q3 [(-4, -5), (-8, -9)]
# Q4 [(1, -3), (3, -2)]

# %% [markdown]
# #### 3. Find the point closest to the center. Calculate its distance to the center.
# Take into account that there might be more than one point at the minimum distance to the center.
#
# **Hint**: Use the Euclidean distance. You can find more information about it [here](https://en.wikipedia.org/wiki/Euclidean_distance).
# **Hint**: Defining a function that calculates the distance to the center can help.

# %%
import math

points = [(4, 5), (-0, 2), (4, 7), (1, -3), (3, -2), (4, 5), (3, 2), (5, 7), (-5, 7), (2, 2), (-4, 5), (0, -2),
          (-4, 7), (-1, 3), (-3, 2), (-4, -5), (-3, 2), (5, 7), (5, 7), (2, 2), (9, 9), (-8, -9)]
r=0
x=0
y=0
a=0
listadist=[]

while r <= 21:
    r=r+1
    m=math.sqrt((points[a][0])**2+(points[a][1])**2)
    print(m)
    listadist.append((m , points[a]))
    a=a+1

listadist.sort()
print(listadist)
print("\nEND the arrow closest to the center is", listadist[0][1], listadist[1][1])
# Out:
# 6.4031242374328485
# 2.0
# 8.06225774829855
# 3.1622776601683795
# 3.605551275463989
# 6.4031242374328485
# 3.605551275463989
# 8.602325267042627
# 8.602325267042627
# 2.8284271247461903
# 6.4031242374328485
# 2.0
# 8.06225774829855
# 3.1622776601683795
# 3.605551275463989
# 6.4031242374328485
# 3.605551275463989
# 8.602325267042627
# 8.602325267042627
# 2.8284271247461903
# 12.727922061357855
# 12.041594578792296
# [(2.0, (0, -2)), (2.0, (0, 2)), (2.8284271247461903, (2, 2)), (2.8284271247461903, (2, 2)), (3.1622776601683795, (-1, 3)), (3.1622776601683795, (1, -3)), (3.605551275463989, (-3, 2)), (3.605551275463989, (-3, 2)), (3.605551275463989, (3, -2)), (3.605551275463989, (3, 2)), (6.4031242374328485, (-4, -5)), (6.4031242374328485, (-4, 5)), (6.4031242374328485, (4, 5)), (6.4031242374328485, (4, 5)), (8.06225774829855, (-4, 7)), (8.06225774829855, (4, 7)), (8.602325267042627, (-5, 7)), (8.602325267042627, (5, 7)), (8.602325267042627, (5, 7)), (8.602325267042627, (5, 7)), (12.041594578792296, (-8, -9)), (12.727922061357855, (9, 9))]
#
# END the arrow closest to the center is (0, -2) (0, 2)

# %% [markdown]
# #### 4. If the archery target has a radius of 9, calculate the number of arrows that won't hit the target.
# **Hint**: Use the function created in step 3.

# %%
import math

points = [(4, 5), (-0, 2), (4, 7), (1, -3), (3, -2), (4, 5), (3, 2), (5, 7), (-5, 7), (2, 2), (-4, 5), (0, -2),
          (-4, 7), (-1, 3), (-3, 2), (-4, -5), (-3, 2), (5, 7), (5, 7), (2, 2), (9, 9), (-8, -9)]
r=0
a=0
arrow=0

while r <= 21:
    r=r+1
    m=math.sqrt((points[a][0])**2+(points[a][1])**2)
    a=a+1
    if m>9:
        arrow=arrow+1

print("\n The number of arrows that won't hit the target is", arrow)
# Out:
#  The number of arrows that won't hit the target is 2
